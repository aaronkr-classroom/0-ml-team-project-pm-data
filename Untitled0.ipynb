# %%
# !pip install path.py
from path import Path
import pandas as pd
import tarfile
import urllib.request

def load_housing_data():
  tarball_path = Path("datasets/housing.tgz")
  if not tarball_path.is_file():
    Path("datasets").mkdir(parents=True, exist_ok=True)
    url = "https://github.com/ageron/data/raw/main/housing.tgz"
    urllib.request.urlretrieve(url, tarball_path)
    with tarfile.open(tarball_path) as housing_tarball:
      housing_tarball.extractall(path="datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))
housing = load_housing_data()
housing.head()
# Out:
# Requirement already satisfied: path.py in /usr/local/lib/python3.10/dist-packages (12.5.0)
# Requirement already satisfied: path in /usr/local/lib/python3.10/dist-packages (from path.py) (17.0.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f48674ac9875> in <cell line: 16>()
#      14       housing_tarball.extractall(path="datasets")
#      15     return pd.read_csv(Path("datasets/housing/housing.csv"))
# ---> 16 housing = load_housing_data()
#      17 housing.head()
#
# <ipython-input-4-f48674ac9875> in load_housing_data()
#       8   tarball_path = Path("datasets/housing.tgz")
#       9   if not tarball_path.is_file():
# ---> 10     Path("datasets").mkdir(parents=True, exist_ok=True)
#      11     url = "https://github.com/ageron/data/raw/main/housing.tgz"
#      12     urllib.request.urlretrieve(url, tarball_path)
#
# TypeError: Path.mkdir() got an unexpected keyword argument 'parents'
